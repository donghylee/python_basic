# %% [markdown]
# # 02-1 자료형과 문자열

# %%
print(type("안녕하세요."))
# Out:
# <class 'str'>

# %%
print("# 하나만 출력합니다.")
# Out:
# # 하나만 출력합니다.

# %%
print("# 여러 개를 출력합니다.")
# Out:
# # 여러 개를 출력합니다.

# %%
print("안녕하세요","저의","이름은","이동형입니다!")
# Out:
# 안녕하세요 저의 이름은 이동형입니다!

# %%
print('"안녕하세요"라고 말했습니다')
# Out:
# "안녕하세요"라고 말했습니다

# %%
print("'안녕하세요'라고 생각만 했습니다.")
# Out:
# '안녕하세요'라고 생각만 했습니다.

# %%
    # 이스케이프 문자열을 사용하면 "''"와 같이 따옴표를 번갈아가며 안써도 된다.
print("\"안녕하세요\"라고 말했습니다.")
# Out:
# "안녕하세요"라고 말했습니다.

# %%
print("이름\t나이\t지역")
print("이동형\t35\t강서구")
print("윤아린\t30\t강서구")
print("구름\t3\t강서구")
# Out:
# 이름	나이	지역
# 이동형	35	강서구
# 윤아린	30	강서구
# 구름	3	강서구

# %%
print("""
동해물과 백두산이 마르고 닳도록
하느님이 보우하사 우리나라 만세
무궁화 삼천리 화려강산 대한사람
대한으로 길이 보전하세
""")
# Out:
# 동해물과 백두산이 마르고 닳도록 하느님이 보우하사 우리나라 만세 무궁화 삼천리 화려강산 대한사람 대한으로 길이 보전하세

# %%
print("""\
동해물고 백두산이 마르고 닳도록
하느님이 보우하사 우리나라 만세
무궁화 삼천리 화려강산 대한사람
대한으로 길이 보전하세\
""")
# Out:
# 동해물고 백두산이 마르고 닳도록 하느님이 보우하사 우리나라 만세 무궁화 삼천리 화려강산 대한사람 대한으로 길이 보전하세

# %%
print("문자 선택 연산자에 대해 알아볼까요?")
print("안녕하세요"[0])
print("안녕하세요"[1])
print("안녕하세요"[2])
print("안녕하세요"[3])
print("안녕하세요"[4])
# Out:
# 문자 선택 연산자에 대해 알아볼까요?
# 안
# 녕
# 하
# 세
# 요

# %%
print("문자 선택 연산자에 대해 알아볼까요?")
print("안녕하세요"[-1])
print("안녕하세요"[-2])
print("안녕하세요"[-3])
print("안녕하세요"[-4])
print("안녕하세요"[-5])
# Out:
# 문자 선택 연산자에 대해 알아볼까요?
# 요
# 세
# 하
# 녕
# 안

# %%
print(2+2-2*2/2*2)
# Out:
# 0.0

# %%
string = "안녕하세요"
string += "!"
string += "!"
print("string:", string)
# Out:
# string: 안녕하세요!!

# %%
input("인사말을 입력하세요>")
# Out:
# '안녕하세요'

# %%
string = input("인사말을 입력하세요>")

# %%
print(string)
# Out:
# 안녕하세요

# %%
#입력을 받습니다.
string = input("입력>")

#출력합니다.
print("자료:", string)
print("자료형:", type(string))
# Out:
# 자료: 입력
# 자료형: <class 'str'>

# %%
#입력을 받습니다.
string = input("입력>")

#출력합니다.
print("입력+100:", string+100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       1 #입력을 받습니다.
#       2 string = input("입력>")
#       3
#       4 #출력합니다.
# ----> 5 print("입력+100:", string+100)
#
# TypeError: can only concatenate str (not "int") to str

# %%
string_a = input("입력A> ")
int_a = int(string_a)

string_b = input("입력B> ")
int_b = int(string_b)

print("문자열 자료:", string_a + string_b)
print("숫자 자료:", int_a + int_b)
# Out:
# 문자열 자료: 27352
# 숫자 자료: 325

# %%
output_a = int("52")
output_b = float("52.273")

print(type(output_a), output_a)
print(type(output_b), output_b)
# Out:
# <class 'int'> 52
# <class 'float'> 52.273

# %%
input_a = int(input("첫 번째 숫자> "))
input_b = int(input("두 번째 숫자> "))

print("덧셈 결과:", input_a + input_b)
print("뺄셈 결과:", input_a - input_b)
print("곱셈 결과:", input_a * input_b)
print("나눗셈 결과:", input_a / input_b)
# Out:
# 덧셈 결과: 325
# 뺄셈 결과: 221
# 곱셈 결과: 14196
# 나눗셈 결과: 5.25
