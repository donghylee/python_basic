# %% [markdown]
# # 제어문 / 조건문(if)

# %%
    # 돈이 있으면 택시를 타고 가고, 돈이 없으면 걸어간다.
money = True
if money:
    print("택시를 타고 가라")
else:
    print("걸어 가라")
# Out:
# 택시를 타고 가라

# %%
money = False
if money:
    print("택시를 타고 가라")
else:
    print("걸어 가라")
# Out:
# 걸어 가라

# %% [markdown]
# ## 1. if문의 기본 구조

# %% [markdown]
# 들여쓰기 방법

# %%
money = True
if money:
    print("택시를")
print("타고")
    print("가라")
# Out:
#   Cell In[6], line 5
#     print("가라")
#     ^
# IndentationError: unexpected indent

# %%
money = True
if money:
    print("택시를")
    print("타고")
        print("가라")
# Out:
#   Cell In[4], line 5
#     print("가라")
#     ^
# IndentationError: unexpected indent

# %%
    # : 을 잊지 말자!!!
money = True
if money
    print("택시를")
    print("타고")
    print("가라")
# Out:
#   Cell In[7], line 2
#     if money
#             ^
# SyntaxError: expected ':'

# %% [markdown]
# ## 2. 연산자

# %% [markdown]
# 비교 연산자

# %%
x = 3
y = 2

# %%
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
x >= y
# Out:
# True

# %%
money = 5000
if money >=3500:
    print("택시를 타고 가라")
else:
    print("걸어 가라")
# Out:
# 택시를 타고 가라

# %% [markdown]
# 논리 연산자

# %%
money = 2000
card = True
if money >= 3000 or card:
    print('택시를 타고 가라')
else:
    print('걸어 가라')
# Out:
# 택시를 타고 가라

# %% [markdown]
# in / not in 연산자

# %%
1 in [1,2,3]
# Out:
# True

# %%
1 not in [1,2,3]
# Out:
# False

# %%
'a' in {'a', 'b','c'}
# Out:
# True

# %%
'a' not in {'a','b','c'}
# Out:
# False

# %%
'j' not in 'python'
# Out:
# True

# %%
pocket=['paper', 'cellphone', 'money', 'wallet']
if 'money' in pocket:
    print('택시를 타고 가라')
else:
    print('걸어 가라')
# Out:
# 택시를 타고 가라

# %% [markdown]
# 조건문에서 아무 일도 하지 않게 설정하고 싶다면?

# %%
if 'money' in pocket:
    pass
else:
    print('카드를 꺼내라')

# %% [markdown]
# ## 3. 다양한 조건을 판단하는 elif

# %%
    # if와 else만으로 표현

pocket = ['paper', 'cellphone']
card = True

if 'money' in pocket:
    print('택시를 타고 가라')
else:
    if card:
        print('택시를 타고 가라')
    else:
        print('걸어 가라')
# Out:
# 택시를 타고 가라

# %%
    # elif를 사용

if 'money' in pocket:
    print('택시를 타고 가라')
elif card:
    print('택시를 타고 가라')
else:
    print('걸어가라')
# Out:
# 택시를 타고 가라

# %%
    # if문을 한 줄로 작성하기.
if 'money' in pocket: pass
else : print('카드를 꺼내라')
# Out:
# 카드를 꺼내라

# %% [markdown]
# ## 4. 조건부 표현식

# %%
    # 조건문
score = 65

if score >= 60:
    message = "success"
else:
    message = "failure"

print(message)
# Out:
# success

# %%
    # 조건부 표현식
score = 50

message = "success" if score >= 60 else "failure"

print(message)
# Out:
# failure
